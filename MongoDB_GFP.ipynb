# %% [markdown]
# ## Connecting with a MongoDB on the cloud
#
# + First, create an account in mlab.com
# + Build a free instance of 0,5GM
# + Create a Database and an User, and connect to it

# %%
import pandas as pd
import pymongo

try:
    conn=pymongo.MongoClient("mongodb://ubird:1617ubird@ds031845.mlab.com:31845/gfp_ubird")
    print "Connected successfully!!!"
except pymongo.errors.ConnectionFailure, e:
    print "Could not connect to MongoDB: %s" % e 
conn
#Create a database using db = conn.gfp_ubird or dictionary access db = conn['gfp_ubird']
# Out:
# Connected successfully!!!
# MongoClient(host=['ds031845.mlab.com:31845'], document_class=dict, tz_aware=False, connect=True)

# %%
db = conn['gfp_ubird']
db
# Out:
# Database(MongoClient(host=['ds031845.mlab.com:31845'], document_class=dict, tz_aware=False, connect=True), u'gfp_ubird')

# %%
df.to_dict("records")
# Out:
# [{'aaMutations': nan,
#   'medianBrightness': 3.7192121319,
#   'std': 0.10699178958799999,
#   'uniqueBarcodes': 3645},
#  {'aaMutations': 'SA108D',
#   'medianBrightness': 1.30103000388,
#   'std': nan,
#   'uniqueBarcodes': 1},
#  {'aaMutations': 'SA108D:SN144D:SI186V:SM231T:SL234P',
#   'medianBrightness': 1.3010312397200001,
#   'std': nan,
#   'uniqueBarcodes': 1},
#  {'aaMutations': 'SA108D:SY141N:SH146L:SE220G',
#   'medianBrightness': 1.30118904441,
#   'std': nan,
#   'uniqueBarcodes': 1},
#  {'aaMutations': 'SA108G',
#   'medianBrightness': 3.70847807573,
#   'std': 0.020612675097599998,
#   'uniqueBarcodes': 2},
#  {'aaMutations': 'SA108G:SK138M:SR166C:SL234P',
#   'medianBrightness': 3.5827640704,
#   'std': nan,
#   'uniqueBarcodes': 1},
#  {'aaMutations': 'SA108G:SK154E:SF163S:SL192Q:SL193P',
#   'medianBrightness': 1.49957271993,
#   'std': nan,
#   'uniqueBarcodes': 1},
#  {'aaMutations': 'SA108G:SK156R',
#   'medianBrightness': 3.65901297055,
#   'std': nan,
# ...

# %%
import pandas as pd

df = pd.read_table('amino_acid_genotypes_to_brightness.tsv')
df.shape
# Out:
# (54025, 4)

# %%
# Create a collection called "aag_to_b and import to our database
collection = db.aag_to_b
collection.insert_many(df.to_dict("records"))

# %%
import pandas as pd

df = pd.read_table('avGFP_reference_sequence.fa')
collection = db.avgfp_to_b
collection.insert_many(df.to_dict("records"))

# %%
db.collection_names()
# Out:
# [u'aag_to_b', u'avgfp_to_b', u'system.indexes']

# %% [markdown]
# ## FUNCTION

# %%
def connectubird():
    import pandas as pd
    import pymongo

    try:
        conn=pymongo.MongoClient("mongodb://ubird:1617ubird@ds031845.mlab.com:31845/gfp_ubird")
        print "Connected successfully!!!"
    except pymongo.errors.ConnectionFailure, e:
        print "Could not connect to MongoDB: %s" % e 
    conn
    db = conn['gfp_ubird']
    return db

# %%
# to be checked
def exportcollection(tablename,coll):
    import pandas as pd

    df = pd.read_table(tablename)

    # Create a collection called "aag_to_b and import to our database
    collection = coll
    collection.insert_many(df.to_dict("records"))

# %%
connectubird()
# Out:
# Connected successfully!!!
# Database(MongoClient(host=['ds031845.mlab.com:31845'], document_class=dict, tz_aware=False, connect=True), u'gfp_ubird')
