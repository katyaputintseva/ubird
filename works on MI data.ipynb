# %% [markdown]
# ### Mean brightness and std of the mutations with high MI
#
# Things to improve:
#
# * the MI should be done on the singles-doubles-triplets dataframe

# %%
import pandas as pd
import numpy as np 
from scipy import sparse
import matplotlib.pyplot as plt
import seaborn as sns
from load_save_csr import load_sparse_csr, save_sparse_csr
# %matplotlib inline

# %%
mi_df = pd.read_csv('feature_score.csv', index_col=0)
mut_brig = pd.read_csv('mutation_based_df.csv', index_col=0)

# %%
mi_nonz=mi_df[mi_df.score!=0]

# %%
mi_only_mu=pd.concat((mut_brig[mi_nonz.aamutation],mut_brig['medianBrightness']),axis=1)

# %%
bright_mi = []
for mut in xrange(len(mi_nonz.aamutation)):
    bright_mi.append(mi_only_mu[mi_only_mu[mi_nonz.aamutation.iloc[mut]]==1].medianBrightness)

# %%
mi_nonz = mi_nonz.reset_index(drop=True)
mi_nonz['mean_bright']=[np.mean(x) for x in bright_mi]
mi_nonz['std_bright']=[np.std(x) for x in bright_mi]

# %%
mi_nonz.sort_values('score', ascending=False).reset_index().mean_bright.plot(kind='line');

# %%
mi_nonz.sort_values(by='score', ascending=False)
# Out:
#      aamutation         score  mean_bright  std_bright
# 1036      SW55R  8.869128e-03     1.424150    0.199595
# 256       SF98S  8.189925e-03     1.422551    0.177012
# 196      SF128S  7.189335e-03     1.445603    0.262784
# 897       SS63P  6.986861e-03     1.408254    0.150474
# 574       SK83E  6.814624e-03     1.432599    0.205258
# 891       SS28P  6.694049e-03     1.447360    0.214658
# 370      SH167R  6.682419e-03     1.418834    0.158508
# 238       SF81S  6.610267e-03     1.482063    0.374104
# 645       SL58P  6.167318e-03     1.433404    0.185721
# 213       SF25S  6.067728e-03     1.425721    0.185544
# 601       SL16P  6.026236e-03     1.415717    0.152874
# 649       SL62P  6.024801e-03     1.442883    0.254779
# 29        SC46R  5.938567e-03     1.450217    0.265680
# 212       SF25L  5.901583e-03     1.541130    0.485419
# 100      SD214G  5.886750e-03     1.450702    0.268579
# 830       SQ67R  5.872702e-03     1.429909    0.222013
# 1012      SV53A  5.814678e-03     1.475537    0.319424
# 245       SF82S  5.699929e-03     1.544935    0.497558
# 151      SE211G  5.647575e-03     1.432447    0.204106
# 157      SE220G  5.607161e-03     1.861625    0.760292
# 390      SH215R  5.578484e-03     1.427986    0.159246
