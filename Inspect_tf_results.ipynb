# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(rc={'axes.facecolor':'#F5F5F5'})
import numpy as np

# %%
cost = pd.DataFrame.from_csv('/Users/katya/Desktop/test/cost_stats.txt', sep = ',')

# %%
plt.figure(figsize = [15,10])
plt.xlabel('# of iteration')
plt.ylabel('Cost, log')
plt.plot(cost.index, np.log(cost.cost));

# %%
weights = pd.DataFrame.from_csv('/Users/katya/Desktop/test/unique_mutations_scores_iteration_6000.csv')

# %%
plt.figure(figsize = [15,10])
plt.xlabel('Mutation weight')
plt.hist(weights.weight);

# %%
top_mut = []

for i in weights[weights.weight > 2].index:
    top_mut.append(i)

# %%
top_pos = [int(x[2:-1]) for x in top_mut]
top_pos.sort()

# %%
plt.figure(figsize = [15,3])
plt.hist(top_pos);

# %%
top_aa = [x[-1] for x in top_mut]
top_aa.sort()
top_aa
# Out:
# ['A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'C',
#  'D',
#  'F',
#  'G',
#  'G',
#  'G',
#  'G',
#  'H',
#  'I',
#  'K',
#  'K',
#  'K',
#  'K',
#  'M',
#  'P',
#  'P',
#  'R',
#  'R',
#  'S',
#  'S',
#  'T',
#  'V',
#  'V',
#  'W',
#  'Y',
#  'Y',
#  'Y']

# %%
set(top_aa)
# Out:
# {'A',
#  'C',
#  'D',
#  'F',
#  'G',
#  'H',
#  'I',
#  'K',
#  'M',
#  'P',
#  'R',
#  'S',
#  'T',
#  'V',
#  'W',
#  'Y'}
