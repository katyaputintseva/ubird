# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
barcodes = pd.DataFrame.from_csv('/Users/katya/MSc/ADS/GFP/barcodes_to_brightness.tsv', sep = '\t')

# %%
plt.figure(figsize = [15,10])
plt.hist(barcodes.brightness)
plt.title('Brightness distribution among barcodes')
plt.xlabel('Brightness');

# %%
aa = barcodes.groupby(by = 'aaMutations').median()

# %%
plt.figure(figsize = [15,10])
plt.hist(aa.brightness)
plt.title('Brightness distribution among aa mutatants')
plt.xlabel('Brightness');

# %%
nt = barcodes.groupby(by = 'nMutations').median()

# %%
plt.figure(figsize = [15,10])
plt.hist(aa.brightness)
plt.title('Brightness distribution among nt mutatants')
plt.xlabel('Brightness');

# %%
print 'We have %d barcodes, %d phenotypes, and %d genotypes in our data' % (len(barcodes), len(aa), len(nt))
# Out:
# We have 68039 barcodes, 54024 phenotypes, and 58416 genotypes in our data

# %%
grouped = barcodes.groupby('aaMutations')
grouped = grouped.aggregate(lambda x: tuple(x))
