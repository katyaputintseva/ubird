# %%
# type "ps -ax" to see all the stuffs running

# %%
from IPython.core.display import HTML
def css_styling():   
    styles = open("styles/custom.css", "r").read() 
    return HTML(styles)

# %% [markdown]
# # 1 Introduction to MongoDB
# <small>This introduction is partially inspired on the notes of Alberto Negron's [blog](http://altons.github.io/python/2013/01/21/gentle-introduction-to-mongodb-using-pymongo/)</small>

# %% [markdown]
# MongoDB is a document-oriented database, part of the NoSQL family of database systems. MongoDB stores structured data as JSON-like structures. From a pythonic point of view it is like storing dictionary data structures. One of its main feature is its schema-less feature, i.e. it supports dynamic schemas. A schema in a relational database informally referst to the structure of the data it stores, i.e. what kind of data, which tables, which relations, etc.

# %% [markdown]
# First of all let us configure the MongoDB system.
#
# + Download mongoDB.
# + Create data directory:
#         mkdir -p /Data/db
# + Check that the server works
#         mongod --nojournal &
# + Check the connection to the server:
#         in another terminal write `mongo`, check that it does not raise any error and exit the console.
# + Close the mongo daemon (mongod).
#         You may have to kill mongod with
#         killall mongod
#         and remove the lock on the daemon,
#         rm /data/db/mongod.lock.
# + Let us configure a little the data base by configuring the path of the data storage and log files. Create a [mongo.conf](./mongo.conf) file such as the one provided  and start the server using the following command:
#
#         mongod --config=./mongo.conf --nojournal &
# + Bonus: we can check the database status using  http://127.0.0.1:28017/
# + Install pymongo
#         pip install pymongo

# %% [markdown]
# ### Connect to a MongoDB database

# %%
import pymongo

# Connection to Mongo DB
try:
    conn=pymongo.MongoClient()
    print "Connected successfully!!!"
except pymongo.errors.ConnectionFailure, e:
    print "Could not connect to MongoDB: %s" % e 
conn
# Out:
# Connected successfully!!!
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %% [markdown]
# We can **create** a database using attribute access <span style = "font-family:Courier;"> db = conn.name_db</span> or dictionary acces <span style = "font-family:Courier;"> db = conn[name_db]</span>.

# %%
#Create a database using db = conn.name_db or dictionary access db = conn['name_db']
db = conn['ads']
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'ads')

# %% [markdown]
# If you need to know what databases are available:

# %%
conn.database_names()      #Empty databases do not show
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-3-c91ec4c1af95> in <module>()
# ----> 1 conn.database_names()      #Empty databases do not show
#
# //anaconda/lib/python2.7/site-packages/pymongo/mongo_client.pyc in database_names(self)
#    1086         return [db["name"] for db in
#    1087                 self._database_default_options('admin').command(
# -> 1088                     "listDatabases")["databases"]]
#    1089
#    1090     def drop_database(self, name_or_database):
#
# //anaconda/lib/python2.7/site-packages/pymongo/database.pyc in command(self, command, value, check, allowable_errors, read_preference, codec_options, **kwargs)
#     476         """
#     477         client = self.__client
# --> 478         with client._socket_for_reads(read_preference) as (sock_info, slave_ok):
#     479             return self._command(sock_info, command, slave_ok, value,
#     480                                  check, allowable_errors, read_preference,
#
# //anaconda/lib/python2.7/contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# //anaconda/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _socket_for_reads(self, read_preference)
#     796         topology = self._get_topology()
#     797         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# --> 798         with self._get_socket(read_preference) as sock_info:
#     799             slave_ok = (single and not sock_info.is_mongos) or (
#     800                 preference != ReadPreference.PRIMARY)
#
# //anaconda/lib/python2.7/contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# //anaconda/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _get_socket(self, selector)
#     760     @contextlib.contextmanager
#     761     def _get_socket(self, selector):
# --> 762         server = self._get_topology().select_server(selector)
#     763         try:
#     764             with server.get_socket(self.__all_credentials) as sock_info:
#
# //anaconda/lib/python2.7/site-packages/pymongo/topology.pyc in select_server(self, selector, server_selection_timeout, address)
#     208         return random.choice(self.select_servers(selector,
#     209                                                  server_selection_timeout,
# --> 210                                                  address))
#     211
#     212     def select_server_by_address(self, address,
#
# //anaconda/lib/python2.7/site-packages/pymongo/topology.pyc in select_servers(self, selector, server_selection_timeout, address)
#     184                 if server_timeout == 0 or now > end_time:
#     185                     raise ServerSelectionTimeoutError(
# --> 186                         self._error_message(selector))
#     187
#     188                 self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused

# %% [markdown]
# We already created 1 new database. Why didn't show up with the above command? Well, databases with no collections or with empty collections will not show up with database_names(). Same goes when we try to list empty collections in a database.
#
# We'll test it again once we have populate some collections.

# %% [markdown]
# ## Collections

# %% [markdown]
# A database stores a **collection**. A collection is a group of documents stored in MongoDB, and can be thought of as the equivalent of a table in a relational database. Getting a collection in PyMongo works the same as getting a database:

# %%
collection = db.edu    # edu is the name of my collection
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'ads'), u'edu')

# %%
db.collection_names()   #Empty collections do not show
# Out:
# []

# %% [markdown]
# However one must be careful when trying to get existing collections. For example, if you have a collection db.user and you type db.usr this is clearly a mistake. Unlike an RDBMS, MongoDB won't protect you from this class of mistake.

# %% [markdown]
# ## Documents

# %% [markdown]
# MongoDB stores structured data as JSON-like documents, using dynamic schemas (called BSON), rather than predefined schemas. An element of data is called a document, and documents are stored in collections. One collection may have any number of documents.
#
# Compared to relational databases, we could say collections are like tables, and documents are like records. But there is one big difference: every record in a table has the same fields (with, usually, differing values) in the same order, while each document in a collection can have completely different fields from the other documents.
#
# All you really need to know when you're using Python, however, is that documents are Python dictionaries that can have strings as keys and can contain various primitive types (int, float,unicode, datetime) as well as other documents (Python dicts) and arrays (Python lists).
#
# To insert some data into MongoDB, all we need to do is create a dict and call .insert() on the collection object. Let us exemplify this process by getting some DatFrame and storing it in the collection.

# %%
import pandas as pd
df = pd.read_csv('./educ_figdp_1_Data.csv',na_values=':')
df.head(5)
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED  Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...    NaN                NaN
# 1  Total public expenditure on education as % of ...    NaN                NaN
# 2  Total public expenditure on education as % of ...   5.00                  e
# 3  Total public expenditure on education as % of ...   5.03                  e
# 4  Total public expenditure on education as % of ...   4.95                  e

# %%
df.to_dict("records")
# Out:
# [{'Flag and Footnotes': nan,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': nan},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.0},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.03},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.92},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.91},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.92},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.04},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.38},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.41},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (28 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.25},
#  {'Flag and Footnotes': 's',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.91},
#  {'Flag and Footnotes': 's',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.99},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.0},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.04},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.92},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.91},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.93},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.04},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.38},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.41},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (27 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.25},
#  {'Flag and Footnotes': 's',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.94},
#  {'Flag and Footnotes': 's',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.02},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.03},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.06},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.98},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.93},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.06},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.41},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.46},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'European Union (25 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.31},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': nan},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.87},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.89},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.8},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.72},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.69},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.79},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.94},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.31},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.28},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (18 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.15},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': nan},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.86},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.89},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.8},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.72},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.69},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.79},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.94},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.31},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.28},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (17 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.15},
#  {'Flag and Footnotes': 'u',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': 's',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.98},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.01},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.04},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.96},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.89},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.87},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.81},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.32},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.29},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (15 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.16},
#  {'Flag and Footnotes': 'u',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': 's',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.97},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.0},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.04},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.95},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.89},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.87},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.8},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.94},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.32},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.28},
#  {'Flag and Footnotes': 'e',
#   'GEO': 'Euro area (13 countries)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.15},
#  {'Flag and Footnotes': 'u',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.99},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 6.09},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 6.02},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.95},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.92},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.98},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 6.0},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 6.43},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 6.57},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 6.58},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Belgium',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 6.55},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 3.88},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 3.7},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 3.94},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.09},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.4},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.25},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.04},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 3.88},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.44},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 4.58},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.1},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Bulgaria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 3.82},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 3.83},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 3.93},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.15},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.32},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.2},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.08},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.42},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.05},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 3.92},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 4.36},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.25},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Czech Republic',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.51},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 8.28},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 8.44},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 8.44},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 8.33},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 8.43},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 8.3},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 7.97},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 7.81},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 7.68},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 8.74},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 8.81},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Denmark',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 8.75},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.45},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.51},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.72},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.74},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.62},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.57},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.43},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.49},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.57},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.06},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.08},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Germany (until 1990 former territory of the FRG)',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.98},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.57},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.24},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.47},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.29},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.92},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.88},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.7},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.72},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.61},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 6.03},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.66},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Estonia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.16},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.29},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.24},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.27},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.35},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.66},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.72},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.73},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.92},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.67},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 6.43},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 6.41},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Ireland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 6.15},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 3.71},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 3.5},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 3.57},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 3.56},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 3.83},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.09},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Greece',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.28},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.24},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.25},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.28},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.25},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.23},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.26},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.34},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.62},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.02},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.98},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Spain',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.82},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 6.04},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.95},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.9},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.92},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.8},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.67},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.61},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.62},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.62},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.9},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.86},
#  {'Flag and Footnotes': nan,
#   'GEO': 'France',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.68},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.52},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 4.83},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.6},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.72},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.56},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 4.41},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 4.67},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.27},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.56},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 4.7},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.5},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Italy',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.29},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.42},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.98},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 6.6},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 7.37},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 6.77},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 6.95},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 7.02},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 6.95},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 7.45},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 7.98},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 7.92},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Cyprus',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 7.87},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.64},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 7.22},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 6.6},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.58},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.12},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.14},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.13},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.07},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.71},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.59},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.96},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Latvia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.96},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.63},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.86},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.81},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Lithuania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.14},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Lithuania',
# ...
#  {'Flag and Footnotes': nan,
#   'GEO': 'Netherlands',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.93},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.66},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.74},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.68},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.53},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.48},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.44},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.4},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.33},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.47},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.98},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.91},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Austria',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.8},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 4.87},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.42},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.41},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.35},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.41},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.47},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.25},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.91},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.08},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.09},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.17},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Poland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.94},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.42},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.39},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.33},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.38},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.1},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.21},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.07},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.1},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 4.89},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.79},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.62},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Portugal',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.27},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 2.88},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 3.25},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 3.51},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 3.45},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 3.28},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 3.48},
#  {'Flag and Footnotes': 'u',
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 4.25},
#  {'Flag and Footnotes': 'u',
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 4.24},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 3.53},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Romania',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 3.07},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': nan},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 5.86},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 5.76},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 5.8},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 5.74},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 5.73},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 5.72},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.15},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 5.2},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 5.69},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 5.68},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Slovenia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 5.68},
#  {'Flag and Footnotes': 'i',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 3.92},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 3.99},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 4.31},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 4.3},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 4.19},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 3.85},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 3.8},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 3.62},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 3.61},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 4.09},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 4.22},
#  {'Flag and Footnotes': 'd',
#   'GEO': 'Slovakia',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 4.06},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2000,
#   'Value': 5.89},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2001,
#   'Value': 6.06},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2002,
#   'Value': 6.22},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2003,
#   'Value': 6.43},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2004,
#   'Value': 6.42},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2005,
#   'Value': 6.3},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2006,
#   'Value': 6.18},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2007,
#   'Value': 5.9},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2008,
#   'Value': 6.1},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2009,
#   'Value': 6.81},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2010,
#   'Value': 6.85},
#  {'Flag and Footnotes': nan,
#   'GEO': 'Finland',
#   'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
#   'TIME': 2011,
#   'Value': 6.76}]

# %%
#insert documents in the collection
collection.insert_many(df.to_dict("records"))
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-7-aaf251948a13> in <module>()
#       1 #insert documents in the collection
# ----> 2 collection.insert_many(df.to_dict("records"))
#
# //anaconda/lib/python2.7/site-packages/pymongo/collection.pyc in insert_many(self, documents, ordered, bypass_document_validation)
#     682         blk = _Bulk(self, ordered, bypass_document_validation)
#     683         blk.ops = [doc for doc in gen()]
# --> 684         blk.execute(self.write_concern.document)
#     685         return InsertManyResult(inserted_ids, self.write_concern.acknowledged)
#     686
#
# //anaconda/lib/python2.7/site-packages/pymongo/bulk.pyc in execute(self, write_concern)
#     464
#     465         client = self.collection.database.client
# --> 466         with client._socket_for_writes() as sock_info:
#     467             if not write_concern.acknowledged:
#     468                 self.execute_no_results(sock_info, generator)
#
# //anaconda/lib/python2.7/contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# //anaconda/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _get_socket(self, selector)
#     760     @contextlib.contextmanager
#     761     def _get_socket(self, selector):
# --> 762         server = self._get_topology().select_server(selector)
#     763         try:
#     764             with server.get_socket(self.__all_credentials) as sock_info:
#
# //anaconda/lib/python2.7/site-packages/pymongo/topology.pyc in select_server(self, selector, server_selection_timeout, address)
#     208         return random.choice(self.select_servers(selector,
#     209                                                  server_selection_timeout,
# --> 210                                                  address))
#     211
#     212     def select_server_by_address(self, address,
#
# //anaconda/lib/python2.7/site-packages/pymongo/topology.pyc in select_servers(self, selector, server_selection_timeout, address)
#     184                 if server_timeout == 0 or now > end_time:
#     185                     raise ServerSelectionTimeoutError(
# --> 186                         self._error_message(selector))
#     187
#     188                 self._ensure_opened()
#
# ServerSelectionTimeoutError: ds013848.mlab.com:13848: timed out

# %%
#Check that we have a non empty collection.
db.collection_names()
# Out:
# [u'edu']

# %% [markdown]
# To recap, we have databases containing collections. A collection is made up of documents. Each document is made up of fields.

# %% [markdown]
# ### Retrieving data

# %%
collection.find_one() #Returns one random document in the collection
# Out:
# {u'Flag and Footnotes': nan,
#  u'GEO': u'European Union (28 countries)',
#  u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined',
#  u'TIME': 2000,
#  u'Value': nan,
#  u'_id': ObjectId('581b293bdda8541712f4c043')}

# %% [markdown]
# To get more than a single document as the result of a query we use the find() method. find() returns a Cursor instance, which allows us to iterate over all matching documents.

# %%
collection.find()

# %%
for d in collection.find():
    print d
# Out:
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c043'), u'GEO': u'European Union (28 countries)'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c044'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 5.0, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c045'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 5.03, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c046'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 4.95, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c047'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 4.92, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c048'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 4.91, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c049'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 4.92, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c04a'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 5.04, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c04b'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 5.38, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c04c'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 5.41, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c04d'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 5.25, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c04e'), u'GEO': u'European Union (28 countries)'}
# {u'Value': 4.91, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': u's', u'_id': ObjectId('581b293bdda8541712f4c04f'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 4.99, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': u's', u'_id': ObjectId('581b293bdda8541712f4c050'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 5.0, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c051'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 5.04, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c052'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 4.95, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c053'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 4.92, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c054'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 4.91, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c055'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 4.93, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c056'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 5.04, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c057'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 5.38, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c058'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 5.41, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c059'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 5.25, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c05a'), u'GEO': u'European Union (27 countries)'}
# {u'Value': 4.94, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': u's', u'_id': ObjectId('581b293bdda8541712f4c05b'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 5.02, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': u's', u'_id': ObjectId('581b293bdda8541712f4c05c'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 5.03, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c05d'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 5.06, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c05e'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 4.98, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c05f'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 4.95, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c060'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 4.93, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c061'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 4.95, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c062'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 5.06, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c063'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 5.41, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c064'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 5.46, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c065'), u'GEO': u'European Union (25 countries)'}
# {u'Value': 5.31, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c066'), u'GEO': u'European Union (25 countries)'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c067'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c068'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': 4.87, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c069'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': 4.89, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c06a'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': 4.8, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c06b'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': 4.72, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c06c'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': 4.69, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c06d'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': 4.79, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c06e'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': 4.94, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c06f'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': 5.31, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c070'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': 5.28, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c071'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': 5.15, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c072'), u'GEO': u'Euro area (18 countries)'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c073'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c074'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': 4.86, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c075'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': 4.89, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c076'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': 4.8, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c077'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': 4.72, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c078'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': 4.69, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c079'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': 4.79, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c07a'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': 4.94, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c07b'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': 5.31, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c07c'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': 5.28, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c07d'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': 5.15, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c07e'), u'GEO': u'Euro area (17 countries)'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': u'u', u'_id': ObjectId('581b293bdda8541712f4c07f'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 4.98, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': u's', u'_id': ObjectId('581b293bdda8541712f4c080'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 5.01, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c081'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 5.04, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c082'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 4.96, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c083'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 4.89, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c084'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 4.87, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c085'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 4.81, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c086'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 4.95, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c087'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 5.32, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c088'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 5.29, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c089'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': 5.16, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c08a'), u'GEO': u'Euro area (15 countries)'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': u'u', u'_id': ObjectId('581b293bdda8541712f4c08b'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 4.97, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': u's', u'_id': ObjectId('581b293bdda8541712f4c08c'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 5.0, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c08d'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 5.04, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c08e'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 4.95, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c08f'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 4.89, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c090'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 4.87, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c091'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 4.8, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c092'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 4.94, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c093'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 5.32, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c094'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 5.28, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c095'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': 5.15, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'e', u'_id': ObjectId('581b293bdda8541712f4c096'), u'GEO': u'Euro area (13 countries)'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': u'u', u'_id': ObjectId('581b293bdda8541712f4c097'), u'GEO': u'Belgium'}
# {u'Value': 5.99, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': u'i', u'_id': ObjectId('581b293bdda8541712f4c098'), u'GEO': u'Belgium'}
# {u'Value': 6.09, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c099'), u'GEO': u'Belgium'}
# {u'Value': 6.02, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c09a'), u'GEO': u'Belgium'}
# {u'Value': 5.95, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c09b'), u'GEO': u'Belgium'}
# {u'Value': 5.92, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c09c'), u'GEO': u'Belgium'}
# {u'Value': 5.98, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c09d'), u'GEO': u'Belgium'}
# {u'Value': 6.0, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c09e'), u'GEO': u'Belgium'}
# {u'Value': 6.43, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c09f'), u'GEO': u'Belgium'}
# {u'Value': 6.57, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0a0'), u'GEO': u'Belgium'}
# {u'Value': 6.58, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0a1'), u'GEO': u'Belgium'}
# {u'Value': 6.55, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0a2'), u'GEO': u'Belgium'}
# {u'Value': 3.88, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0a3'), u'GEO': u'Bulgaria'}
# {u'Value': 3.7, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0a4'), u'GEO': u'Bulgaria'}
# {u'Value': 3.94, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0a5'), u'GEO': u'Bulgaria'}
# {u'Value': 4.09, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0a6'), u'GEO': u'Bulgaria'}
# {u'Value': 4.4, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0a7'), u'GEO': u'Bulgaria'}
# {u'Value': 4.25, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0a8'), u'GEO': u'Bulgaria'}
# {u'Value': 4.04, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0a9'), u'GEO': u'Bulgaria'}
# {u'Value': 3.88, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0aa'), u'GEO': u'Bulgaria'}
# {u'Value': 4.44, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0ab'), u'GEO': u'Bulgaria'}
# {u'Value': 4.58, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0ac'), u'GEO': u'Bulgaria'}
# {u'Value': 4.1, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0ad'), u'GEO': u'Bulgaria'}
# {u'Value': 3.82, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0ae'), u'GEO': u'Bulgaria'}
# {u'Value': 3.83, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0af'), u'GEO': u'Czech Republic'}
# {u'Value': 3.93, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0b0'), u'GEO': u'Czech Republic'}
# {u'Value': 4.15, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0b1'), u'GEO': u'Czech Republic'}
# {u'Value': 4.32, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0b2'), u'GEO': u'Czech Republic'}
# {u'Value': 4.2, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0b3'), u'GEO': u'Czech Republic'}
# {u'Value': 4.08, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0b4'), u'GEO': u'Czech Republic'}
# {u'Value': 4.42, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0b5'), u'GEO': u'Czech Republic'}
# {u'Value': 4.05, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0b6'), u'GEO': u'Czech Republic'}
# {u'Value': 3.92, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0b7'), u'GEO': u'Czech Republic'}
# {u'Value': 4.36, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0b8'), u'GEO': u'Czech Republic'}
# {u'Value': 4.25, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0b9'), u'GEO': u'Czech Republic'}
# {u'Value': 4.51, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0ba'), u'GEO': u'Czech Republic'}
# {u'Value': 8.28, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': u'i', u'_id': ObjectId('581b293bdda8541712f4c0bb'), u'GEO': u'Denmark'}
# {u'Value': 8.44, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0bc'), u'GEO': u'Denmark'}
# {u'Value': 8.44, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0bd'), u'GEO': u'Denmark'}
# {u'Value': 8.33, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0be'), u'GEO': u'Denmark'}
# {u'Value': 8.43, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0bf'), u'GEO': u'Denmark'}
# {u'Value': 8.3, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0c0'), u'GEO': u'Denmark'}
# {u'Value': 7.97, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0c1'), u'GEO': u'Denmark'}
# {u'Value': 7.81, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0c2'), u'GEO': u'Denmark'}
# {u'Value': 7.68, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0c3'), u'GEO': u'Denmark'}
# {u'Value': 8.74, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0c4'), u'GEO': u'Denmark'}
# {u'Value': 8.81, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0c5'), u'GEO': u'Denmark'}
# {u'Value': 8.75, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0c6'), u'GEO': u'Denmark'}
# {u'Value': 4.45, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0c7'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 4.51, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0c8'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 4.72, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0c9'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 4.74, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0ca'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 4.62, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0cb'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 4.57, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0cc'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 4.43, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0cd'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 4.49, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0ce'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 4.57, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0cf'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 5.06, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0d0'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 5.08, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0d1'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 4.98, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0d2'), u'GEO': u'Germany (until 1990 former territory of the FRG)'}
# {u'Value': 5.57, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': u'i', u'_id': ObjectId('581b293bdda8541712f4c0d3'), u'GEO': u'Estonia'}
# {u'Value': 5.24, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0d4'), u'GEO': u'Estonia'}
# {u'Value': 5.47, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0d5'), u'GEO': u'Estonia'}
# {u'Value': 5.29, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0d6'), u'GEO': u'Estonia'}
# {u'Value': 4.92, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0d7'), u'GEO': u'Estonia'}
# {u'Value': 4.88, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0d8'), u'GEO': u'Estonia'}
# {u'Value': 4.7, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0d9'), u'GEO': u'Estonia'}
# {u'Value': 4.72, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c0da'), u'GEO': u'Estonia'}
# {u'Value': 5.61, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0db'), u'GEO': u'Estonia'}
# {u'Value': 6.03, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0dc'), u'GEO': u'Estonia'}
# {u'Value': 5.66, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0dd'), u'GEO': u'Estonia'}
# {u'Value': 5.16, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0de'), u'GEO': u'Estonia'}
# {u'Value': 4.29, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0df'), u'GEO': u'Ireland'}
# {u'Value': 4.24, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0e0'), u'GEO': u'Ireland'}
# {u'Value': 4.27, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0e1'), u'GEO': u'Ireland'}
# {u'Value': 4.35, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0e2'), u'GEO': u'Ireland'}
# {u'Value': 4.66, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0e3'), u'GEO': u'Ireland'}
# {u'Value': 4.72, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0e4'), u'GEO': u'Ireland'}
# {u'Value': 4.73, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0e5'), u'GEO': u'Ireland'}
# {u'Value': 4.92, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0e6'), u'GEO': u'Ireland'}
# {u'Value': 5.67, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0e7'), u'GEO': u'Ireland'}
# {u'Value': 6.43, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0e8'), u'GEO': u'Ireland'}
# {u'Value': 6.41, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0e9'), u'GEO': u'Ireland'}
# {u'Value': 6.15, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0ea'), u'GEO': u'Ireland'}
# {u'Value': 3.71, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': u'i', u'_id': ObjectId('581b293bdda8541712f4c0eb'), u'GEO': u'Greece'}
# {u'Value': 3.5, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': u'i', u'_id': ObjectId('581b293bdda8541712f4c0ec'), u'GEO': u'Greece'}
# {u'Value': 3.57, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'i', u'_id': ObjectId('581b293bdda8541712f4c0ed'), u'GEO': u'Greece'}
# {u'Value': 3.56, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'i', u'_id': ObjectId('581b293bdda8541712f4c0ee'), u'GEO': u'Greece'}
# {u'Value': 3.83, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'i', u'_id': ObjectId('581b293bdda8541712f4c0ef'), u'GEO': u'Greece'}
# {u'Value': 4.09, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0f0'), u'GEO': u'Greece'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0f1'), u'GEO': u'Greece'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0f2'), u'GEO': u'Greece'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0f3'), u'GEO': u'Greece'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0f4'), u'GEO': u'Greece'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0f5'), u'GEO': u'Greece'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0f6'), u'GEO': u'Greece'}
# {u'Value': 4.28, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0f7'), u'GEO': u'Spain'}
# {u'Value': 4.24, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0f8'), u'GEO': u'Spain'}
# {u'Value': 4.25, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0f9'), u'GEO': u'Spain'}
# {u'Value': 4.28, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0fa'), u'GEO': u'Spain'}
# {u'Value': 4.25, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0fb'), u'GEO': u'Spain'}
# {u'Value': 4.23, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0fc'), u'GEO': u'Spain'}
# {u'Value': 4.26, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0fd'), u'GEO': u'Spain'}
# {u'Value': 4.34, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0fe'), u'GEO': u'Spain'}
# {u'Value': 4.62, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c0ff'), u'GEO': u'Spain'}
# {u'Value': 5.02, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c100'), u'GEO': u'Spain'}
# {u'Value': 4.98, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c101'), u'GEO': u'Spain'}
# {u'Value': 4.82, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c102'), u'GEO': u'Spain'}
# {u'Value': 6.04, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c103'), u'GEO': u'France'}
# {u'Value': 5.95, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c104'), u'GEO': u'France'}
# {u'Value': 5.9, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c105'), u'GEO': u'France'}
# {u'Value': 5.92, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c106'), u'GEO': u'France'}
# {u'Value': 5.8, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c107'), u'GEO': u'France'}
# {u'Value': 5.67, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c108'), u'GEO': u'France'}
# ...
# {u'Value': 5.35, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c17e'), u'GEO': u'Poland'}
# {u'Value': 5.41, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c17f'), u'GEO': u'Poland'}
# {u'Value': 5.47, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c180'), u'GEO': u'Poland'}
# {u'Value': 5.25, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c181'), u'GEO': u'Poland'}
# {u'Value': 4.91, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c182'), u'GEO': u'Poland'}
# {u'Value': 5.08, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c183'), u'GEO': u'Poland'}
# {u'Value': 5.09, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c184'), u'GEO': u'Poland'}
# {u'Value': 5.17, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c185'), u'GEO': u'Poland'}
# {u'Value': 4.94, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c186'), u'GEO': u'Poland'}
# {u'Value': 5.42, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c187'), u'GEO': u'Portugal'}
# {u'Value': 5.39, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c188'), u'GEO': u'Portugal'}
# {u'Value': 5.33, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c189'), u'GEO': u'Portugal'}
# {u'Value': 5.38, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c18a'), u'GEO': u'Portugal'}
# {u'Value': 5.1, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c18b'), u'GEO': u'Portugal'}
# {u'Value': 5.21, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c18c'), u'GEO': u'Portugal'}
# {u'Value': 5.07, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c18d'), u'GEO': u'Portugal'}
# {u'Value': 5.1, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c18e'), u'GEO': u'Portugal'}
# {u'Value': 4.89, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c18f'), u'GEO': u'Portugal'}
# {u'Value': 5.79, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c190'), u'GEO': u'Portugal'}
# {u'Value': 5.62, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c191'), u'GEO': u'Portugal'}
# {u'Value': 5.27, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c192'), u'GEO': u'Portugal'}
# {u'Value': 2.88, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c193'), u'GEO': u'Romania'}
# {u'Value': 3.25, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c194'), u'GEO': u'Romania'}
# {u'Value': 3.51, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c195'), u'GEO': u'Romania'}
# {u'Value': 3.45, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c196'), u'GEO': u'Romania'}
# {u'Value': 3.28, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c197'), u'GEO': u'Romania'}
# {u'Value': 3.48, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c198'), u'GEO': u'Romania'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'u', u'_id': ObjectId('581b293bdda8541712f4c199'), u'GEO': u'Romania'}
# {u'Value': 4.25, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c19a'), u'GEO': u'Romania'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'u', u'_id': ObjectId('581b293bdda8541712f4c19b'), u'GEO': u'Romania'}
# {u'Value': 4.24, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c19c'), u'GEO': u'Romania'}
# {u'Value': 3.53, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c19d'), u'GEO': u'Romania'}
# {u'Value': 3.07, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c19e'), u'GEO': u'Romania'}
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c19f'), u'GEO': u'Slovenia'}
# {u'Value': 5.86, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1a0'), u'GEO': u'Slovenia'}
# {u'Value': 5.76, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1a1'), u'GEO': u'Slovenia'}
# {u'Value': 5.8, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1a2'), u'GEO': u'Slovenia'}
# {u'Value': 5.74, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1a3'), u'GEO': u'Slovenia'}
# {u'Value': 5.73, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1a4'), u'GEO': u'Slovenia'}
# {u'Value': 5.72, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1a5'), u'GEO': u'Slovenia'}
# {u'Value': 5.15, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1a6'), u'GEO': u'Slovenia'}
# {u'Value': 5.2, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1a7'), u'GEO': u'Slovenia'}
# {u'Value': 5.69, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1a8'), u'GEO': u'Slovenia'}
# {u'Value': 5.68, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1a9'), u'GEO': u'Slovenia'}
# {u'Value': 5.68, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1aa'), u'GEO': u'Slovenia'}
# {u'Value': 3.92, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': u'i', u'_id': ObjectId('581b293bdda8541712f4c1ab'), u'GEO': u'Slovakia'}
# {u'Value': 3.99, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1ac'), u'GEO': u'Slovakia'}
# {u'Value': 4.31, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1ad'), u'GEO': u'Slovakia'}
# {u'Value': 4.3, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1ae'), u'GEO': u'Slovakia'}
# {u'Value': 4.19, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1af'), u'GEO': u'Slovakia'}
# {u'Value': 3.85, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1b0'), u'GEO': u'Slovakia'}
# {u'Value': 3.8, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1b1'), u'GEO': u'Slovakia'}
# {u'Value': 3.62, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1b2'), u'GEO': u'Slovakia'}
# {u'Value': 3.61, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1b3'), u'GEO': u'Slovakia'}
# {u'Value': 4.09, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1b4'), u'GEO': u'Slovakia'}
# {u'Value': 4.22, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1b5'), u'GEO': u'Slovakia'}
# {u'Value': 4.06, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': u'd', u'_id': ObjectId('581b293bdda8541712f4c1b6'), u'GEO': u'Slovakia'}
# {u'Value': 5.89, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2000, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1b7'), u'GEO': u'Finland'}
# {u'Value': 6.06, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2001, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1b8'), u'GEO': u'Finland'}
# {u'Value': 6.22, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2002, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1b9'), u'GEO': u'Finland'}
# {u'Value': 6.43, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2003, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1ba'), u'GEO': u'Finland'}
# {u'Value': 6.42, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2004, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1bb'), u'GEO': u'Finland'}
# {u'Value': 6.3, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2005, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1bc'), u'GEO': u'Finland'}
# {u'Value': 6.18, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2006, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1bd'), u'GEO': u'Finland'}
# {u'Value': 5.9, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2007, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1be'), u'GEO': u'Finland'}
# {u'Value': 6.1, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2008, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1bf'), u'GEO': u'Finland'}
# {u'Value': 6.81, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2009, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1c0'), u'GEO': u'Finland'}
# {u'Value': 6.85, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2010, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1c1'), u'GEO': u'Finland'}
# {u'Value': 6.76, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2011, u'Flag and Footnotes': nan, u'_id': ObjectId('581b293bdda8541712f4c1c2'), u'GEO': u'Finland'}

# %% [markdown]
# If we just want to know how many documents match a query we can perform a count() operation instead of a full query. We can get a count of all of the documents in a collection:

# %%
collection.count()
# Out:
# 384

# %% [markdown]
# ### Basic queries

# %% [markdown]
# Querying in pymongo uses .find()

# %%
collection.find({"TIME":2009}).count()
# Out:
# 32

# %%
collection.find({"GEO":"Spain"}).count()
# Out:
# 12

# %% [markdown]
# Observe that it finds exact matches.

# %%
collection.find({"TIME":"2009"}).count()
# Out:
# 0

# %%
collection.find({"GEO":"SPAIN"}).count()
# Out:
# 0

# %% [markdown]
# Operations include *gt* (greater than), *gte* (greater than equal), *lt* (lesser than), *lte* (lesser than equal), *ne* (not equal), *nin* (not in a list), *regex* (regular expression), *exists*, *not*, *or*, *and*, etc. Let us see some examples:

# %%
collection.find({"TIME":{"$gte":2009}}).count()
# Out:
# 96

# %%
substring = "Euro"
reg = substring
collection.find({"GEO":{"$regex":reg}}).count()
# Out:
# 84

# %%
for item in collection.find({"GEO":{"$regex":reg}}):
    print item['GEO']
# Out:
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (28 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (27 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# European Union (25 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (18 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (17 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (15 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)
# Euro area (13 countries)

# %% [markdown]
# ### Update

# %% [markdown]
# In this section, several methods for updating and deleting documents are reveiwed:
#
# + Update. This method finds the documents defined by query and **replaces** it by the new document.

# %%
import numpy as np
doc = {'Flag and Footnotes': np.nan,
  'GEO': 'Catalunya',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': np.nan}
collection.insert_one(doc)

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print doc
# Out:
# {u'Value': nan, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2017, u'Flag and Footnotes': nan, u'_id': ObjectId('581b2991dda8541712f4c1c3'), u'GEO': u'Catalunya'}

# %%
newdoc = {'Flag and Footnotes': np.nan,
  'GEO': 'Catalunya',
  'INDIC_ED': 'Total public expenditure on education as % of GDP, for all levels of education combined',
  'TIME': 2017,
  'Value': 15}
collection.replace_one({'GEO':"Catalunya"},newdoc)

for doc in collection.find({'GEO':"Catalunya"}):
    print doc
# Out:
# {u'Value': 15, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2017, u'Flag and Footnotes': nan, u'_id': ObjectId('581b2991dda8541712f4c1c3'), u'GEO': u'Catalunya'}

# %% [markdown]
# If we don't want to write again all the document and just put the field that we want to change then we have to use update_one and adding a sub-command.  Let us check some of them:

# %% [markdown]
# + Sub-command **Set**:
#
# This statement updates in the document in collection where field matches value1 by replacing the value of the field field1 with value2. This operator will add the specified field or fields if they do not exist in this document or replace the existing value of the specified field(s) if they already exist.
#
# An upsert eliminates the need to perform a separate database call to check for the existence of a record before performing either an update or an insert operation. Typically update operations update existing documents, but in MongoDB, the update_one() operation can accept an upsert option as an argument. Upserts are a hybrid operation that use the query argument to determine the write operation:
#
# If the query matches an existing document(s), the upsert performs an update.
# If the query matches no document in the collection, the upsert inserts a single document.

# %%
collection.update_one({'GEO':"Catalunya"},{"$set":{"Value":12}})

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print doc
# Out:
# {u'Value': 12, u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'TIME': 2017, u'Flag and Footnotes': nan, u'_id': ObjectId('581b2991dda8541712f4c1c3'), u'GEO': u'Catalunya'}

# %% [markdown]
# By default, if the filter doesn't return any document, nothing is inserted to database. If you want to insert it, then set the upsert flag to `True`

# %%
collection.update_one({'GEO':"Andorra"},{"$set":{"Value":12}},upsert = True)
for doc in collection.find({'GEO':"Andorra"}):
    print doc
# Out:
# {u'_id': ObjectId('581b2996609c277df77dbe1b'), u'GEO': u'Andorra', u'Value': 12}

# %% [markdown]
# + Sub-commnad **Unset**:
#
# The unset operator deletes a particular field. If documents match the initial query but do not have the field specified in the unset operation, there the statement has no effect on the document.

# %%
collection.update_one({'GEO':"Catalunya"},{"$unset":{"Flag and Footnotes":""}})

# %%
for doc in collection.find({'GEO':"Catalunya"}):
    print doc
# Out:
# {u'INDIC_ED': u'Total public expenditure on education as % of GDP, for all levels of education combined', u'_id': ObjectId('581b2991dda8541712f4c1c3'), u'GEO': u'Catalunya', u'Value': 12, u'TIME': 2017}

# %% [markdown]
# ### Delete operations

# %% [markdown]
# We can remove elements by simply:

# %%
collection.delete_one({"GEO":"Andorra"})

# %%
for doc in collection.find({"GEO":"Andorra"}):
    print doc

# %% [markdown]
# And remove a collection by:

# %%
db.collection_names()
# Out:
# [u'edu']

# %%
db.drop_collection("edu")
db.collection_names()
# Out:
# []

# %% [markdown]
# And remove a database by:

# %%
conn.database_names()
# Out:
# [u'local']

# %%
conn.drop_database('test')
conn.database_names()
# Out:
# [u'local']

# %% [markdown]
# And finally close the connection with the database.

# %%
conn.close()

# %% [markdown]
# ## Connecting with a MongoDB on the cloud
#
# + First, create an account in mlab.com
# + Build a free instance of 0,5GM
# + Create a Database and an User, and connect to it

# %%
import pandas as pd
import pymongo

try:
    conn=pymongo.MongoClient("mongodb://xiaoxia:51Master.@ds013848.mlab.com:13848/ads")
    
    print "Connected successfully!!!"
except pymongo.errors.ConnectionFailure, e:
    print "Could not connect to MongoDB: %s" % e 
conn


#Create a database using db = conn.name_db or dictionary access db = conn['name_db']
db = conn['ads']
print db

# Create a collection called "edu" and insert
collection = db.edu
collection.insert_many(df.to_dict("records"))
# Out:
# Connected successfully!!!
# Database(MongoClient(host=['ds013848.mlab.com:13848'], document_class=dict, tz_aware=False, connect=True), u'ads')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f783a1847ed8> in <module>()
#      17 # Create a collection called "edu" and insert
#      18 collection = db.edu
# ---> 19 collection.insert_many(df.to_dict("records"))
#
# NameError: name 'df' is not defined

# %% [markdown]
# You can check your mongoDB database in this website:
# [https://mlab.com/databases/ads#collections](https://mlab.com/databases/ads#collections)

# %%
db.drop_collection("edu")
conn.close()
