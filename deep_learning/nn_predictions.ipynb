# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
input_file = '~/amino_acid_genotypes_to_brightness_reuse.tsv'
train_file = '~/amino_acid_genotypes_to_brightness.tsv'
model_file = '/Users/katya/net_1_1_3_iteration_07020.ckpt'
learning_rate = 0.1
batch_size = 628
optimizer_method = 'tf.train.AdagradOptimizer'
line = 'net_structure\t1,tf.tanh\t3,tf.tanh\t1,tf.tanh'
net_structure = {}
counter = 1
for i in line.split('\t')[1:]:
    net_structure['layer' + str(counter)] = i.split(',')
    counter += 1

# %%
train_data = pd.read_table(train_file)
train_data.aaMutations = train_data.aaMutations.fillna('')
unique_mutations = set(':'.join(train_data.aaMutations).split(':'))
unique_mutations.remove('')
unique_mutations = sorted(list(unique_mutations))

data = pd.read_table(input_file)
data.aaMutations = data.aaMutations.fillna('')

# %%
def density_plot(x, y):
    ''' x = observed, y = predicted '''
    x = x[(~np.isnan(x)) & (~np.isnan(y))]
    y = y[(~np.isnan(x)) & (~np.isnan(y))]
    xy = np.vstack([x, y])
    z = gaussian_kde(xy)(xy)
    idx = z.argsort()
    x, y, z = x[idx], y[idx], z[idx]
    fig, ax = plt.subplots()
    ax.scatter(x, y, c=z, s=10, edgecolor='')


def format_plot(ax, iteration_number, costs):
    plt.xlim(-1, 1)
    plt.ylim(-1, 1)
    plt.xlabel('Observed brightness')
    plt.ylabel('Predicted brightness')
    plt.title('Iteration %s: cost=%.7f' % (iteration_number, costs))

    plt.tick_params(axis="both", which="both", bottom="off", top="off",
                    labelbottom="on", left="off", right="off", labelleft="on")
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(True)
    ax.spines["bottom"].set_color('gray')
    ax.spines["left"].set_visible(True)
    ax.spines["left"].set_color('gray')
    ax.xaxis.grid(True)
    ax.yaxis.grid(True)
    return ax


def format_data(data, unique_mutations):
    data = data.reindex(np.random.permutation(data.index))
    print('Normalizing data...')
    nn_genotypes_values = np.zeros((len(data), len(unique_mutations)))
    nn_brightness_values = data.medianBrightness.values
    for i in range(len(unique_mutations)):
        nn_genotypes_values[:, i] = data.aaMutations.str.contains(unique_mutations[i]).astype(np.float32)

    nn_brightness_values = (nn_brightness_values - min(nn_brightness_values)) / max(
        nn_brightness_values - min(nn_brightness_values)) * 2 - 1
    return nn_genotypes_values, nn_brightness_values


def get_batches(nn_genotypes_values, batch_size, unique_mutations):
    print('Creating batches...')
    batches = []
    batch_number = int(nn_genotypes_values.shape[0] / batch_size)
    for i in range(batch_number):
        current_batch = nn_genotypes_values[batch_size * i:batch_size * (i + 1), :].reshape(batch_size, 1,
                                                                                            len(unique_mutations))
        batches.append(current_batch)
    return batches


def broadcast(tensor, batch_size):
    return tf.tile(tensor, (batch_size, 1, 1))

# %%
class Data():
    def __init__(self, input_file, data, unique_mutations, batch_size):
        self.data = data
        self.unique_mutations = unique_mutations
        self.batch_size = batch_size
        self.input_file = input_file
        self.nn_genotypes_values, self.nn_brightness_values = format_data(data, self.unique_mutations)
        self.batches = get_batches(self.nn_genotypes_values, self.batch_size,
                                   self.unique_mutations)
        self.batch_number = len(self.batches)
        self.to_plot_observed = self.nn_brightness_values[0:(self.batch_number * self.batch_size)]
        self.nn_genotypes = tf.placeholder(tf.float32, shape=[self.batch_size, 1, len(self.unique_mutations)])
        self.nn_brightness = tf.placeholder(tf.float32, shape=[self.batch_size, 1, 1])


class TFNet(object):
    def __init__(self, net_structure, input_data, optimizer_method, learning_rate, batch_size):

        self.number_of_layers = len(net_structure)
        self.structure = net_structure

        self.neurons = {}
        self.weights = {}
        self.biases = {}
        self.input = {}
        self.output = {}

        for i in range(self.number_of_layers):
            layer = 'layer' + str(i + 1)
            self.neurons[layer] = int(self.structure[layer][0])
            self.weights[layer] = tf.Variable(
                tf.random_normal([1, len(input_data.unique_mutations), self.neurons[layer]]),
                name=layer + '_weights')
            self.biases[layer] = tf.Variable(tf.random_normal([1, 1, self.neurons[layer]]), name=layer + '_biases')
            self.input[layer] = tf.add(
                tf.batch_matmul(input_data.nn_genotypes, broadcast(self.weights[layer], batch_size)),
                broadcast(self.biases[layer], batch_size))
            self.output[layer] = eval(self.structure[layer][1])(self.input[layer])
            print(self.weights[layer].name)
        self.init = tf.initialize_all_variables()
        self.saver = tf.train.Saver()


    def __str__(self):
        print('Net structure:\n')
        for i in range(self.number_of_layers):
            print('%s neurons in layer_' % (self.neurons['layer' + str(i + 1)]) + str(i + 1) + '\n')

# %%
data = Data(input_file, data, unique_mutations, batch_size)
net = TFNet(net_structure, data, optimizer_method, learning_rate, batch_size)
# Out:
# Normalizing data...
# Creating batches...
# layer1_weights:0
# layer2_weights:0
# layer3_weights:0

# %%
with tf.Session() as sess:
    sess.run(net.init)
    net.saver.restore(sess, model_file)
    for batch in data.batches:
        to_plot_predicted = np.zeros(data.batch_number * batch_size)
        for index, (batch) in enumerate(data.batches):
            l3_value = sess.run([net.output['layer3']],
                                feed_dict={data.nn_genotypes: batch})

# %%
l3_value
# Out:
# [array([[[-0.53800195]],
#
#         [[-0.8464579 ]],
#
#         [[-0.99879664]],
#
#         [[-0.99990314]],
#
#         [[ 0.30580652]],
#
#         [[-0.54432237]],
#
#         [[-0.85454386]],
#
#         [[-0.08458158]],
#
#         [[ 0.69978005]],
#
#         [[-0.99922889]],
#
#         [[-0.99783093]],
#
#         [[-0.99997115]],
#
#         [[ 0.45677391]],
#
#         [[ 0.57830232]],
#
#         [[ 0.51293743]],
#
#         [[-0.99808782]],
#
#         [[-0.99583638]],
#
#         [[ 0.31356314]],
#
#         [[-0.9061628 ]],
#
#         [[-0.99909347]],
#
#         [[ 0.64612859]],
#
#         [[ 0.39084938]],
#
#         [[ 0.12606183]],
#
#         [[-0.99349195]],
#
#         [[-0.99993449]],
#
#         [[-0.98433244]],
#
#         [[-0.98335892]],
#
#         [[ 0.40780243]],
#
#         [[-0.94400722]],
#
#         [[ 0.74454421]],
#
#         [[-0.94006538]],
#
#         [[-0.99999392]],
#
#         [[-0.64740932]],
#
#         [[-0.99996161]],
#
#         [[-0.62445569]],
#
#         [[-0.93872255]],
#
#         [[ 0.76820445]],
#
#         [[-0.96599895]],
#
#         [[ 0.72898972]],
#
#         [[-0.87299711]],
#
#         [[-0.99985051]],
#
#         [[ 0.85018474]],
#
#         [[-0.99249727]],
#
#         [[ 0.66450769]],
#
#         [[-0.99999738]],
#
#         [[-0.92816305]],
#
#         [[-0.92134529]],
#
#         [[-0.99993175]],
#
#         [[-0.99938279]],
#
#         [[-0.83977318]],
#
#         [[-0.99869728]],
#
#         [[ 0.82505673]],
#
#         [[ 0.83218473]],
#
#         [[ 0.54086965]],
#
#         [[-0.99838281]],
#
#         [[-0.91929501]],
#
#         [[ 0.36179489]],
#
#         [[-0.99986345]],
#
#         [[ 0.66750497]],
#
#         [[-0.99998897]],
#
#         [[-0.96569979]],
#
#         [[ 0.54345536]],
#
#         [[-0.75406533]],
#
#         [[-0.94160944]],
#
#         [[-0.99999642]],
#
#         [[-0.99495786]],
#
#         [[ 0.80844468]],
#
#         [[-0.74345785]],
#
#         [[ 0.61092496]],
#
#         [[ 0.81978798]],
#
#         [[-0.9554261 ]],
#
#         [[ 0.71639228]],
#
#         [[-0.56595594]],
#
#         [[-0.98963493]],
#
#         [[-0.43502218]],
#
#         [[ 0.7161963 ]],
#
#         [[ 0.29121178]],
#
#         [[-0.80162483]],
#
#         [[-0.99515802]],
#
#         [[-0.99623191]],
#
#         [[ 0.83698899]],
#
#         [[-0.99967915]],
#
#         [[-0.99962729]],
#
#         [[-0.3013615 ]],
#
#         [[-0.33312672]],
#
#         [[ 0.67527854]],
#
#         [[ 0.83032721]],
#
#         [[ 0.35030386]],
#
#         [[ 0.39479002]],
#
#         [[-0.34448701]],
#
#         [[-0.99998331]],
#
#         [[-0.95311826]],
#
#         [[ 0.4758442 ]],
#
#         [[ 0.46781564]],
#
#         [[-0.94734472]],
#
#         [[-0.99477857]],
#
#         [[ 0.28006569]],
#
#         [[-0.96656585]],
#
#         [[ 0.86384493]],
#
#         [[-0.59199774]],
#
#         [[-0.99954337]],
#
#         [[ 0.80448574]],
#
#         [[ 0.76436591]],
#
#         [[ 0.5952788 ]],
#
#         [[ 0.82769579]],
#
#         [[ 0.71146828]],
#
#         [[-0.99739528]],
#
#         [[ 0.33668432]],
#
#         [[-0.94484621]],
#
#         [[-0.99598223]],
#
#         [[-0.99999714]],
#
#         [[-0.71961278]],
#
#         [[-0.92038268]],
#
#         [[-0.99996215]],
#
#         [[-0.99780244]],
#
#         [[ 0.36177424]],
#
#         [[ 0.868954  ]],
#
#         [[-0.99907184]],
#
#         [[-0.99904388]],
#
#         [[ 0.64337575]],
#
#         [[-0.91595119]],
#
#         [[-0.94922131]],
#
#         [[-0.98141372]],
#
#         [[-0.9999575 ]],
#
#         [[ 0.79472733]],
#
#         [[-0.99990273]],
#
#         [[-0.9450627 ]],
#
#         [[-0.99911976]],
#
#         [[-0.13691643]],
#
#         [[-0.93892294]],
#
#         [[ 0.77233154]],
#
#         [[-0.94018328]],
#
#         [[-0.89546448]],
#
#         [[-0.9834156 ]],
#
#         [[ 0.88831031]],
#
#         [[ 0.86901462]],
#
#         [[-0.80130154]],
#
#         [[-0.99031031]],
#
#         [[-0.99664372]],
#
#         [[-0.99790192]],
#
#         [[ 0.11251763]],
#
#         [[ 0.19373775]],
#
#         [[-0.94240123]],
#
#         [[-0.84091395]],
#
#         [[ 0.72734696]],
#
#         [[-0.78421229]],
#
#         [[-0.99989974]],
#
#         [[-0.99818569]],
#
#         [[-0.99994797]],
#
#         [[-0.99840301]],
#
#         [[ 0.77312154]],
#
#         [[-0.92086095]],
#
#         [[ 0.80208981]],
#
#         [[ 0.67211962]],
#
#         [[ 0.82815397]],
#
#         [[ 0.46795571]],
#
#         [[-0.70205545]],
#
#         [[ 0.55933869]],
#
#         [[-0.99602008]],
#
#         [[-0.81959432]],
#
#         [[-0.96586382]],
#
#         [[-0.97888243]],
#
#         [[-0.78886122]],
#
#         [[-0.96820498]],
#
#         [[-0.99400449]],
#
#         [[ 0.48649982]],
#
#         [[-0.99991715]],
#
#         [[ 0.5009746 ]],
#
#         [[-0.99801689]],
#
#         [[-0.92942697]],
#
#         [[-0.78936595]],
#
#         [[ 0.64739817]],
#
#         [[ 0.63310385]],
#
#         [[-0.9998045 ]],
#
#         [[-0.88125515]],
#
#         [[ 0.68495464]],
#
#         [[-0.97720599]],
#
#         [[ 0.26420552]],
#
#         [[-0.9942044 ]],
#
#         [[ 0.49823573]],
#
#         [[-0.99479479]],
#
#         [[-0.90914428]],
#
#         [[-0.90998822]],
#
#         [[ 0.41539603]],
#
#         [[-0.83224803]],
#
#         [[-0.99769908]],
#
#         [[-0.8643136 ]],
#
#         [[-0.99995607]],
#
#         [[-0.99966836]],
#
#         [[-0.99774003]],
#
#         [[-0.99568433]],
#
#         [[-0.61972833]],
#
#         [[-0.67615575]],
#
#         [[ 0.52389854]],
#
#         [[ 0.70504963]],
#
#         [[-0.99997532]],
#
#         [[-0.99630487]],
#
#         [[-0.91891026]],
#
#         [[-0.91326809]],
#
#         [[-0.99991834]],
#
#         [[-0.99999601]],
#
#         [[-0.95012337]],
#
#         [[-0.99946314]],
#
#         [[ 0.43047187]],
#
#         [[-0.99530196]],
#
#         [[ 0.89578307]],
#
#         [[-0.9461332 ]],
#
#         [[-0.98121047]],
#
#         [[-0.96980846]],
#
#         [[-0.82943684]],
#
#         [[ 0.23856564]],
#
#         [[ 0.92743349]],
#
#         [[ 0.56449115]],
#
#         [[-0.99928778]],
#
#         [[-0.99260265]],
#
#         [[ 0.23945315]],
#
#         [[-0.99933362]],
#
#         [[-0.95349675]],
#
#         [[-0.9998703 ]],
#
#         [[-0.99343812]],
#
#         [[-0.99999934]],
#
#         [[ 0.85685468]],
#
#         [[-0.98974055]],
#
#         [[-0.83475053]],
#
#         [[-0.88224345]],
#
#         [[ 0.23330159]],
#
#         [[-0.91074961]],
#
#         [[ 0.66550297]],
#
#         [[-0.38837573]],
#
#         [[ 0.43637031]],
#
#         [[-0.99960637]],
#
#         [[-0.8174687 ]],
#
#         [[ 0.75790387]],
#
#         [[-0.97233874]],
#
#         [[-0.99998903]],
#
#         [[-0.89606816]],
#
#         [[-0.97641587]],
#
#         [[ 0.48029181]],
#
#         [[-0.99681914]],
#
#         [[-0.99272931]],
#
#         [[ 0.63085067]],
#
#         [[ 0.40065977]],
#
#         [[-0.92880821]],
#
#         [[-0.98540962]],
#
#         [[-0.99992108]],
#
#         [[-0.99803066]],
#
#         [[-0.99446619]],
#
#         [[-0.99661636]],
#
#         [[-0.63292921]],
#
#         [[-0.80678511]],
#
#         [[-0.99964273]],
#
#         [[-0.99886811]],
#
#         [[-0.9998765 ]],
#
#         [[-0.98027021]],
#
#         [[-0.85435957]],
#
#         [[ 0.81057107]],
#
#         [[ 0.21431127]],
#
#         [[-0.99855596]],
#
#         [[-0.81138933]],
#
#         [[-0.90194225]],
#
#         [[-0.99825317]],
#
#         [[ 0.25986683]],
#
#         [[-0.99936569]],
#
#         [[-0.85900003]],
#
#         [[ 0.20159365]],
#
#         [[-0.99922574]],
#
#         [[-0.68886578]],
#
#         [[-0.99986541]],
#
#         [[-0.71687859]],
#
#         [[-0.99840492]],
#
#         [[ 0.59557086]],
#
#         [[-0.83231896]],
#
#         [[-0.4496879 ]],
#
#         [[ 0.36745191]],
#
#         [[-0.99567097]],
#
#         [[-0.78730553]],
#
#         [[-0.99993551]],
#
#         [[ 0.42988735]],
#
#         [[-0.92553687]],
#
#         [[ 0.83946174]],
#
#         [[-0.99999934]],
#
#         [[ 0.70360005]],
#
#         [[-0.99478447]],
#
#         [[-0.27114835]],
#
#         [[ 0.84812325]],
#
#         [[-0.96313059]],
#
#         [[ 0.83654225]],
#
#         [[-0.96701658]],
#
#         [[-0.98889446]],
#
#         [[-0.99993736]],
#
#         [[ 0.69575906]],
#
#         [[-0.98633206]],
#
#         [[ 0.64693874]],
#
#         [[-0.95341659]],
#
#         [[-0.95355409]],
#
#         [[ 0.59764814]],
#
#         [[-0.99619567]],
#
#         [[-0.65776253]],
#
#         [[-0.90406674]],
#
#         [[-0.91944599]],
#
#         [[-0.99961942]],
#
#         [[ 0.82493019]],
#
#         [[-0.97493935]],
#
#         [[-0.999991  ]],
#
#         [[-0.99949855]],
#
#         [[-0.8161971 ]],
#
#         [[-0.53407866]],
#
#         [[-0.99997222]],
#
#         [[-0.92679828]],
#
#         [[ 0.78375161]],
#
#         [[ 0.11802226]],
#
#         [[ 0.43322888]],
#
#         [[-0.98165727]],
#
#         [[-0.74607939]],
#
#         [[-0.59144568]],
#
#         [[ 0.69555414]],
#
#         [[-0.67018062]],
#
#         [[-0.99998063]],
#
#         [[-0.98876733]],
#
#         [[ 0.7729786 ]],
#
#         [[ 0.44701901]],
#
#         [[ 0.68689787]],
#
#         [[-0.58359545]],
#
#         [[-0.99994552]],
#
#         [[-0.6311084 ]],
#
#         [[ 0.83060062]],
#
#         [[-0.9620167 ]],
#
#         [[-0.98241758]],
#
#         [[ 0.84523726]],
#
#         [[-0.97141296]],
#
#         [[ 0.39575335]],
#
#         [[ 0.28607005]],
#
#         [[-0.91977823]],
#
#         [[-0.97508866]],
#
#         [[ 0.54787302]],
#
#         [[-0.99999791]],
#
#         [[ 0.78804249]],
#
#         [[ 0.28098789]],
#
#         [[-0.80126911]],
#
#         [[ 0.1594128 ]],
#
#         [[ 0.43274072]],
#
#         [[ 0.6897589 ]],
#
#         [[ 0.41498849]],
#
#         [[-0.99999714]],
#
#         [[-0.96927977]],
#
#         [[-0.91479039]],
#
#         [[-0.9938553 ]],
#
#         [[ 0.86182618]],
#
#         [[-0.94657981]],
#
#         [[-0.96458286]],
#
#         [[ 0.57896364]],
#
#         [[-0.95862639]],
#
#         [[ 0.81462997]],
#
#         [[ 0.59951133]],
#
#         [[-0.99981678]],
#
#         [[ 0.48317254]],
#
#         [[-0.93286645]],
#
#         [[-0.94130433]],
#
#         [[ 0.77458167]],
#
#         [[-0.99997002]],
#
#         [[-0.99963254]],
#
#         [[ 0.84633565]],
#
#         [[ 0.72132957]],
#
#         [[-0.99703449]],
#
#         [[-0.95449299]],
#
#         [[-0.99998885]],
#
#         [[-0.94563109]],
#
#         [[ 0.62168407]],
#
#         [[-0.92985189]],
#
#         [[-0.98335218]],
#
#         [[ 0.64460725]],
#
#         [[-0.9458887 ]],
#
#         [[ 0.72374678]],
#
#         [[-0.97553116]],
#
#         [[-0.99999791]],
#
#         [[ 0.44899145]],
#
#         [[-0.9298802 ]],
#
#         [[ 0.74994767]],
#
#         [[-0.97549397]],
#
#         [[-0.9464981 ]],
#
#         [[ 0.80940348]],
#
#         [[-0.99731767]],
#
#         [[-0.99998349]],
#
#         [[-0.9994058 ]],
#
#         [[ 0.09580535]],
#
#         [[-0.98653984]],
#
#         [[ 0.41101262]],
#
#         [[-0.84510696]],
#
#         [[-0.99300498]],
#
#         [[-0.99989432]],
#
#         [[ 0.72767669]],
#
#         [[-0.99630052]],
#
#         [[ 0.64139044]],
#
#         [[ 0.05512307]],
#
#         [[-0.99801809]],
#
#         [[ 0.7454111 ]],
#
#         [[-0.82039368]],
#
#         [[ 0.84140694]],
#
#         [[-0.99162   ]],
#
#         [[-0.80434227]],
#
#         [[-0.96527052]],
#
#         [[ 0.32076353]],
#
#         [[-0.96361631]],
#
#         [[-0.99998683]],
#
#         [[-0.99991393]],
#
#         [[-0.91498929]],
#
#         [[-0.94714087]],
#
#         [[ 0.5205484 ]],
#
#         [[-0.89697272]],
#
#         [[ 0.82270378]],
#
#         [[-0.99555868]],
#
#         [[-0.99879813]],
#
#         [[-0.9883368 ]],
#
#         [[-0.9999938 ]],
#
#         [[ 0.21400678]],
#
#         [[ 0.73858911]],
#
#         [[-0.95785213]],
#
#         [[ 0.43035918]],
#
#         [[-0.99906743]],
#
#         [[-0.99872404]],
#
#         [[ 0.52921981]],
#
#         [[ 0.74771667]],
#
#         [[-0.99976951]],
#
#         [[-0.96918005]],
#
#         [[-0.97943914]],
#
#         [[-0.99978077]],
#
#         [[-0.93170625]],
#
#         [[ 0.86041093]],
#
#         [[-0.1445138 ]],
#
#         [[-0.99999458]],
#
#         [[-0.98568416]],
#
#         [[-0.97718596]],
#
#         [[-0.9815461 ]],
#
#         [[-0.99892241]],
#
#         [[-0.99978691]],
#
#         [[-0.80420196]],
#
#         [[-0.99462682]],
#
#         [[ 0.23617226]],
#
#         [[-0.9999876 ]],
#
#         [[-0.04094849]],
#
#         [[ 0.75828224]],
#
#         [[-0.99910718]],
#
#         [[-0.9995302 ]],
#
#         [[ 0.64156622]],
#
#         [[ 0.56942171]],
#
#         [[-0.99892831]],
#
#         [[ 0.55144417]],
#
#         [[-0.99179918]],
#
#         [[ 0.88512009]],
#
#         [[-0.91917413]],
#
#         [[-0.99926418]],
#
#         [[ 0.63260591]],
#
#         [[-0.94984084]],
#
#         [[-0.99021786]],
#
#         [[-0.94047785]],
#
#         [[-0.99920905]],
#
#         [[ 0.3564204 ]],
#
#         [[ 0.89441085]],
#
#         [[ 0.51195419]],
#
#         [[ 0.32521412]],
#
#         [[-0.9441762 ]],
#
#         [[-0.99999982]],
#
#         [[ 0.90635413]],
#
#         [[ 0.48433354]],
#
#         [[ 0.60571963]],
#
#         [[ 0.86820054]],
#
#         [[-0.38682953]],
#
#         [[ 0.67509705]],
#
#         [[ 0.58185524]],
#
#         [[-0.9500283 ]],
#
#         [[-0.96448857]],
#
#         [[-0.99994677]],
#
#         [[-0.98158795]],
#
#         [[-0.96434534]],
#
#         [[-0.91889793]],
#
#         [[-0.86488312]],
#
#         [[-0.87630504]],
#
#         [[-0.99852407]],
#
#         [[-0.99772972]],
#
#         [[-0.99814761]],
#
#         [[-0.99974757]],
#
#         [[ 0.15634923]],
#
#         [[ 0.71914548]],
#
#         [[-0.65084708]],
#
#         [[-0.94074869]],
#
#         [[ 0.90268785]],
#
#         [[-0.98054361]],
#
#         [[ 0.46217701]],
#
#         [[-0.98155367]],
#
#         [[-0.99920017]],
#
#         [[ 0.89148301]],
#
#         [[-0.61642575]],
#
#         [[-0.94739324]],
#
#         [[-0.93501145]],
#
#         [[-0.99999726]],
#
#         [[ 0.02076875]],
#
#         [[-0.99998683]],
#
#         [[-0.99999911]],
#
#         [[-0.99089909]],
#
#         [[ 0.82082474]],
#
#         [[-0.96150708]],
#
#         [[-0.99999982]],
#
#         [[-0.65112597]],
#
#         [[-0.97289121]],
#
#         [[ 0.5360387 ]],
#
#         [[-0.99998462]],
#
#         [[ 0.34506261]],
#
#         [[-0.99999982]],
#
#         [[-0.97936916]],
#
#         [[-0.78664303]],
#
#         [[ 0.80444014]],
#
#         [[-0.80194092]],
#
#         [[-0.80139899]],
#
#         [[-0.96965933]],
#
#         [[ 0.72211742]],
#
#         [[-0.99688476]],
#
#         [[-0.82187468]],
#
#         [[-0.80586028]],
#
#         [[-0.99649698]],
#
#         [[ 0.71287656]],
#
#         [[-0.99978846]],
#
#         [[-0.91170019]],
#
#         [[-0.77992058]],
#
#         [[-0.92088497]],
#
#         [[-0.95911127]],
#
#         [[ 0.58670956]],
#
#         [[ 0.84351385]],
#
#         [[-0.99038786]],
#
#         [[ 0.55882657]],
#
#         [[-0.89728111]],
#
#         [[-0.99759406]],
#
#         [[-0.97640467]],
#
#         [[-0.93794304]],
#
#         [[-0.91789407]],
#
#         [[-0.99972457]],
#
#         [[ 0.36526784]],
#
#         [[-0.95600718]],
#
#         [[-0.92933816]],
#
#         [[-0.93155843]],
#
#         [[-0.91649783]],
#
#         [[ 0.9000544 ]],
#
#         [[-0.9944526 ]],
#
#         [[ 0.37237528]],
#
#         [[ 0.63285744]],
#
#         [[ 0.73838019]],
#
#         [[-0.97775829]],
#
#         [[ 0.5615623 ]],
#
#         [[ 0.69268066]],
#
#         [[-0.70794117]],
#
#         [[-0.85909474]],
#
#         [[-0.99998075]],
#
#         [[ 0.33095667]],
#
#         [[-0.99902076]],
#
#         [[ 0.67784554]],
#
#         [[-0.99941564]],
#
#         [[ 0.66740543]],
#
#         [[-0.94680768]],
#
#         [[-0.99691093]],
#
#         [[-0.96878326]],
#
#         [[ 0.67732233]],
#
#         [[ 0.90115309]],
#
#         [[-0.88657612]],
#
#         [[ 0.8074373 ]],
#
#         [[-0.94644839]],
#
#         [[-0.97229159]],
#
#         [[-0.97419608]],
#
#         [[-0.99552238]],
#
#         [[-0.95560038]],
#
#         [[ 0.54509187]],
#
#         [[ 0.50922823]],
#
#         [[-0.89415205]],
#
#         [[-0.99747252]],
#
#         [[-0.94430363]],
#
#         [[-0.99185675]],
#
#         [[-0.99420083]],
#
#         [[ 0.85256368]],
#
#         [[-0.51202983]],
#
#         [[-0.99905849]],
#
#         [[ 0.89527631]],
#
#         [[-0.99950713]],
#
#         [[-0.99994934]],
#
#         [[-0.53593892]],
#
#         [[ 0.11907465]],
#
#         [[ 0.88646829]],
#
#         [[ 0.73305595]],
#
#         [[-0.95907241]],
#
#         [[ 0.07150763]],
#
#         [[ 0.83671862]],
#
#         [[-0.90648448]],
#
#         [[ 0.57599211]],
#
#         [[-0.98906863]],
#
#         [[ 0.86130679]],
#
#         [[-0.99642211]],
#
#         [[ 0.64857286]],
#
#         [[-0.64490831]],
#
#         [[ 0.69776809]],
#
#         [[ 0.8848961 ]],
#
#         [[-0.95548952]],
#
#         [[-0.92404211]],
#
#         [[ 0.55635107]],
#
#         [[ 0.62680346]],
#
#         [[-0.99767083]],
#
#         [[-0.8956306 ]],
#
#         [[-0.99733144]],
#
#         [[-0.99712408]],
#
#         [[-0.8525672 ]],
#
#         [[-0.99920559]],
#
#         [[ 0.89956814]],
#
#         [[-0.99313891]],
#
#         [[-0.99312389]],
#
#         [[-0.83475697]],
#
#         [[-0.9952386 ]],
#
#         [[ 0.72364926]],
#
#         [[ 0.42165568]],
#
#         [[-0.99888617]],
#
#         [[ 0.86782068]],
#
#         [[-0.91546518]],
#
#         [[-0.96007401]],
#
#         [[ 0.84411287]],
#
#         [[ 0.88139409]],
#
#         [[-0.99338275]],
#
#         [[-0.992764  ]],
#
#         [[ 0.87375522]],
#
#         [[-0.97514647]],
#
#         [[ 0.53709573]],
#
#         [[-0.98857474]],
#
#         [[ 0.09403757]],
#
#         [[-0.95615792]]], dtype=float32)]
