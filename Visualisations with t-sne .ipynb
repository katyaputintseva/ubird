# %%
import pandas as pd
import numpy as np 
from scipy import sparse 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from load_save_csr import load_sparse_csr, save_sparse_csr

# %%
X = load_sparse_csr('sparse_csr.npz')

# %%
X
# Out:
# <54024x1882 sparse matrix of type '<type 'numpy.int8'>'
# 	with 320437 stored elements in Compressed Sparse Row format>

# %% [markdown]
# TruncatedSVD for dim reduction to 50

# %%
 from sklearn.decomposition import TruncatedSVD

# %%
svd = TruncatedSVD(n_components=50, n_iter=10, random_state=42)

# %%
X_fit_trans = svd.fit_transform(X, y=None)

# %%
X_trans = svd.transform(X)

# %%
X_trans.shape
# Out:
# (54024L, 50L)

# %%
X_fit_trans.shape
# Out:
# (54024L, 50L)

# %%
print(svd.explained_variance_ratio_) 
print(svd.explained_variance_ratio_.sum())
# Out:
# [ 0.30468462  0.26460038  0.00205446  0.00198012  0.00178542  0.00176181
#   0.00174105  0.0017183   0.00164952  0.00163755  0.00162518  0.00160829
#   0.00159359  0.00158767  0.00157988  0.00155599  0.00154315  0.00153981
#   0.00153163  0.00150894  0.001505    0.00149635  0.00148832  0.00146973
#   0.00146591  0.00145454  0.00144614  0.00144103  0.00142894  0.00141454
#   0.00141183  0.00140298  0.00140064  0.00139321  0.00139064  0.00137553
#   0.00137444  0.00136554  0.00136086  0.0013512   0.00134139  0.0013313
#   0.00132845  0.00131461  0.00130694  0.00129687  0.00129425  0.00128799
#   0.00127923  0.00127398]
# 0.640779762186

# %%
n=len(X_trans)

# %%
idx = np.random.choice(len(X_trans),1000, replace=False)

# %%
x = X_trans[idx]

# %%
x.shape
# Out:
# (1000L, 50L)

# %% [markdown]
# use the t-sne manifold

# %%
from sklearn.manifold import TSNE

# %%
model = TSNE(n_components=2, random_state=0)

# %%
x_tsne=model.fit_transform(x)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import pylab

# %%
fig = pylab.figure()
ax = Axes3D(fig)


ax.scatter(x_tsne[:,0], x_tsne[:,1], x_tsne[:,2])
plt.show();

# %%
plt.scatter(x_tsne[:,0], x_tsne[:,1])
